# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mat 
import seaborn as sns
from tabulate import tabulate

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("appearances.xlsx")
df
# Out:
#        appearance_id  game_id  player_id       date          player_name  \
# 0     2224728_119169  2224728     119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732     161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729      39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104     119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794      39475 2012-07-22       Sacha Kljestan
# ...              ...      ...        ...        ...                  ...
# 3563  3415291_537467  3415291     537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296     367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983     478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575     361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904     124732 2020-09-27  John Anthony Brooks
#
#      competition_id  yellow_cards  red_cards  goals  assists  minutes_played
# ...

# %%
df.isnull().sum()
# Out:
# appearance_id     0
# game_id           0
# player_id         0
# date              0
# player_name       0
# competition_id    0
# yellow_cards      0
# red_cards         0
# goals             0
# assists           0
# minutes_played    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3568 entries, 0 to 3567
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   appearance_id   3568 non-null   object
#  1   game_id         3568 non-null   int64
#  2   player_id       3568 non-null   int64
#  3   date            3568 non-null   datetime64[ns]
#  4   player_name     3568 non-null   object
#  5   competition_id  3568 non-null   object
#  6   yellow_cards    3568 non-null   int64
#  7   red_cards       3568 non-null   int64
#  8   goals           3568 non-null   int64
#  9   assists         3568 non-null   int64
#  10  minutes_played  3568 non-null   int64
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 306.8+ KB

# %%
df.shape
# Out:
# (3568, 11)

# %%
df.columns
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'date', 'player_name',
#        'competition_id', 'yellow_cards', 'red_cards', 'goals', 'assists',
#        'minutes_played'],
#       dtype='object')

# %%
df1 = pd.read_excel("game_events.xlsx")
df1
# Out:
#                          game_event_id       date  game_id  minute  \
# 0     c6a3c088ed8a38d4ce074dd73b20d3da 2012-08-19  2221641      62
# 1     02d605a5c2dc4f9a6721daa583fa5405 2012-08-26  2222536      54
# 2     b56c2e2e087cddb3cfe9e3d340975df9 2012-11-18  2222707      79
# 3     4a15d1fff4f476f48bb60092c61641d5 2012-11-23  2222721      72
# 4     daa97877f7edf2fda885b411d7197921 2013-05-17  2222782      63
# ...                                ...        ...      ...     ...
# 1844  4acebccbc824e45d51045d8c5e164341 2023-10-31  4194147       3
# 1845  159ad5633cf9d7c3a97b593efb6c3269 2023-10-31  4194147       9
# 1846  daa31f19aab26eec375884aef73c73b3 2023-10-31  4194147      65
# 1847  869a13060604e769290dafe0b1f14483 2023-11-01  4194152      70
# 1848  6b7ed06f13c1f67f0d7359c310f20ba0 2023-10-31  4194154      76
#
#                type  player_id  \
# 0     Substitutions       1335
# 1             Cards       1321
# 2     Substitutions     104203
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1849 entries, 0 to 1848
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game_event_id     1849 non-null   object
#  1   date              1849 non-null   datetime64[ns]
#  2   game_id           1849 non-null   int64
#  3   minute            1849 non-null   int64
#  4   type              1849 non-null   object
#  5   player_id         1849 non-null   int64
#  6   description       916 non-null    object
#  7   player_in_id      1155 non-null   float64
#  8   player_assist_id  140 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 130.1+ KB

# %%
df1.shape
# Out:
# (1849, 9)

# %%
df1.columns
# Out:
# Index(['game_event_id', 'date', 'game_id', 'minute', 'type', 'player_id',
#        'description', 'player_in_id', 'player_assist_id'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# game_event_id          0
# date                   0
# game_id                0
# minute                 0
# type                   0
# player_id              0
# description          933
# player_in_id         694
# player_assist_id    1709
# dtype: int64

# %%
df1["description"].value_counts()
# Out:
# description
# , Tactical                                                                              118
# , Not reported                                                                           74
# , Right-footed shot, 1. Goal of the Season                                               42
# 1. Yellow card  , Foul                                                                   39
# , Right-footed shot, 1. Tournament Goal                                                  27
#                                                                                        ...
# , Right-footed shot, 2. Tournament Goal Assist: , Shot on goal, 1. Tournament Assist      1
# , Right-footed shot, 3. Tournament Goal Assist: , Pass, 2. Tournament Assist              1
# , Header, 1. Tournament Goal Assist: , Free kick, 1. Tournament Assist                    1
# , Left-footed shot, 4. Tournament Goal Assist: , Pass, 1. Tournament Assist               1
# ...

# %%
df1["description"].isnull().sum()
# Out:
# 933

# %%
df1["description"] = df1["description"].fillna(", Tactical")

# %%
df1["description"].isnull().sum()
# Out:
# 0

# %%
df1["player_in_id"].isnull().sum()
# Out:
# 694

# %%
df1['player_in_id'] = df1['player_in_id'].fillna(239513)

# %%
df1["player_in_id"].isnull().sum()
# Out:
# 0

# %%
df1["player_assist_id"].isnull().sum()
# Out:
# 1709

# %%
df1['player_assist_id'] = df1['player_assist_id'].fillna(82500)

# %%
df1["player_assist_id"].isnull().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# game_event_id       0
# date                0
# game_id             0
# minute              0
# type                0
# player_id           0
# description         0
# player_in_id        0
# player_assist_id    0
# dtype: int64

# %%
df1
# Out:
#                          game_event_id       date  game_id  minute  \
# 0     c6a3c088ed8a38d4ce074dd73b20d3da 2012-08-19  2221641      62
# 1     02d605a5c2dc4f9a6721daa583fa5405 2012-08-26  2222536      54
# 2     b56c2e2e087cddb3cfe9e3d340975df9 2012-11-18  2222707      79
# 3     4a15d1fff4f476f48bb60092c61641d5 2012-11-23  2222721      72
# 4     daa97877f7edf2fda885b411d7197921 2013-05-17  2222782      63
# ...                                ...        ...      ...     ...
# 1844  4acebccbc824e45d51045d8c5e164341 2023-10-31  4194147       3
# 1845  159ad5633cf9d7c3a97b593efb6c3269 2023-10-31  4194147       9
# 1846  daa31f19aab26eec375884aef73c73b3 2023-10-31  4194147      65
# 1847  869a13060604e769290dafe0b1f14483 2023-11-01  4194152      70
# 1848  6b7ed06f13c1f67f0d7359c310f20ba0 2023-10-31  4194154      76
#
#                type  player_id  \
# 0     Substitutions       1335
# 1             Cards       1321
# 2     Substitutions     104203
# ...

# %%
df2 = pd.read_excel('game_lineups.xlsx')
df2
# Out:
#                       game_lineups_id  game_id             type  number  \
# 0    f2570d1504fc02f4b6c7608e8dcf89a3  4087925      substitutes      34
# 1    f5f0da93ea8e1d8bdd799658e7c8f7cb  4087928  starting_lineup      13
# 2    31a4d12ec23d604779d909d26c1b5410  4087929      substitutes      26
# 3    776dcbef98651450db76723cb7e3b4df  4087935      substitutes      26
# 4    6a35ef7495303f29e7f85dbd54547fb1  4087936  starting_lineup      13
# ..                                ...      ...              ...     ...
# 214  ec3d266094f99ca0a8847de827e37105  4194152  starting_lineup       7
# 215  667840cda9bdf3b0344b8e99b306cf38  4194152  starting_lineup      23
# 216  1c5d2f60ee777760f8a757aa10c42bb1  4194154  starting_lineup      13
# 217  99032084fd00ffbfee52c541a9f960ab  4204000      substitutes      14
# 218  5c9eaf6ebb621d43a0d6fd6a9e607ef9  4220942      substitutes      13
#
#      player_id          player_name  team_captain          position
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_lineups_id  219 non-null    object
#  1   game_id          219 non-null    int64
#  2   type             219 non-null    object
#  3   number           219 non-null    int64
#  4   player_id        219 non-null    int64
#  5   player_name      219 non-null    object
#  6   team_captain     219 non-null    int64
#  7   position         219 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 13.8+ KB

# %%
df2.shape
# Out:
# (219, 8)

# %%
df2.isnull().sum()
# Out:
# game_lineups_id    0
# game_id            0
# type               0
# number             0
# player_id          0
# player_name        0
# team_captain       0
# position           0
# dtype: int64

# %%
df3 = pd.read_excel('games.xlsx')
df3
# Out:
#       game_id competition_id  season         round       date  \
# 0     2222734            RU1    2012  19. Matchday 2012-12-07
# 1     2224572            DK1    2012   3. Matchday 2012-07-28
# 2     2224628            DK1    2012  22. Matchday 2013-03-08
# 3     2224655            DK1    2012  22. Matchday 2013-03-10
# 4     2224729            DK1    2012   1. Matchday 2012-07-15
# ...       ...            ...     ...           ...        ...
# 3263  3296153            NLP    2019   Round of 16 2020-01-22
# 3264  2875216            DK1    2017  19. Matchday 2017-12-10
# 3265  3099247            BE1    2018  11. Matchday 2018-10-20
# 3266  2872273            GB1    2017  16. Matchday 2017-12-09
# 3267  2517322            FAC    2014   Third Round 2015-01-04
#
#       home_club_goals  away_club_goals  home_club_position  \
# 0                   2                3                11.0
# 1                   1                2                12.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 3268 non-null   int64
#  1   competition_id          3268 non-null   object
#  2   season                  3268 non-null   int64
#  3   round                   3268 non-null   object
#  4   date                    3268 non-null   datetime64[ns]
#  5   home_club_goals         3268 non-null   int64
#  6   away_club_goals         3268 non-null   int64
#  7   home_club_position      2789 non-null   float64
#  8   away_club_position      2789 non-null   float64
#  9   home_club_manager_name  3263 non-null   object
#  10  away_club_manager_name  3263 non-null   object
#  11  stadium                 3268 non-null   object
#  12  attendance              3153 non-null   float64
#  13  referee                 3266 non-null   object
# ...

# %%
df3.shape
# Out:
# (3268, 20)

# %%
df3.isnull().sum()
# Out:
# game_id                      0
# competition_id               0
# season                       0
# round                        0
# date                         0
# home_club_goals              0
# away_club_goals              0
# home_club_position         479
# away_club_position         479
# home_club_manager_name       5
# away_club_manager_name       5
# stadium                      0
# attendance                 115
# referee                      2
# home_club_formation       3268
# away_club_formation       3268
# home_club_name             110
# away_club_name              63
# aggregate                    0
# competition_type             0
# dtype: int64

# %%
df3["home_club_formation"].isnull().sum()
# Out:
# 3268

# %%
df3["home_club_formation"] = df3["home_club_formation"].fillna(3)

# %%
df3["home_club_formation"].isnull().sum()
# Out:
# 0

# %%
df3["away_club_formation"].isnull().sum()
# Out:
# 3268

# %%
df3["away_club_formation"] = df3["away_club_formation"].fillna(10)

# %%
df3["away_club_formation"].isnull().sum()
# Out:
# 0

# %%
df3["home_club_manager_name"].isnull().sum()
# Out:
# 5

# %%
df3["home_club_manager_name"].value_counts()
# Out:
# home_club_manager_name
# Mark Hughes            68
# Roberto Martínez       55
# Hein Vanhaezebrouck    54
# John van den Brom      53
# Paul Lambert           53
#                        ..
# Morten Karlsen          1
# Darko Milanic           1
# Joakim Mattsson         1
# John Brown              1
# Luis Freire             1
# Name: count, Length: 580, dtype: int64

# %%
df3["home_club_manager_name"] = df3["home_club_manager_name"].fillna("Mark Hughes")

# %%
df3["home_club_manager_name"].isnull().sum()
# Out:
# 0

# %%
df3["away_club_manager_name"].isnull().sum()
# Out:
# 5

# %%
df3["away_club_manager_name"].value_counts()
# Out:
# away_club_manager_name
# Mark Hughes            71
# Roberto Martínez       57
# Lucien Favre           57
# Paul Lambert           55
# Hein Vanhaezebrouck    54
#                        ..
# Veaceslav Rusnac        1
# Ian Murray              1
# Steve Lovell            1
# Raul Procopio           1
# Kevin Wilkin            1
# Name: count, Length: 550, dtype: int64

# %%
df3["away_club_manager_name"] = df3["away_club_manager_name"].fillna("Mark Hughes")

# %%
df3["away_club_manager_name"].isnull().sum()
# Out:
# 0

# %%
df3["home_club_position"].isnull().sum()
# Out:
# 479

# %%
df3["home_club_position"].value_counts()
# Out:
# home_club_position
# 3.0     202
# 11.0    175
# 4.0     174
# 9.0     173
# 5.0     169
# 2.0     167
# 10.0    165
# 6.0     163
# 7.0     161
# 12.0    154
# 8.0     140
# 13.0    138
# 14.0    137
# 1.0     135
# 17.0    126
# 16.0    125
# 15.0    110
# 18.0     79
# 19.0     51
# 20.0     45
# Name: count, dtype: int64

# %%
df3["home_club_position"] = df3["home_club_position"].fillna(3)

# %%
df3["home_club_position"].isnull().sum()
# Out:
# 0

# %%
df3["away_club_position"].isnull().sum()
# Out:
# 479

# %%
df3["away_club_position"].value_counts()
# Out:
# away_club_position
# 10.0    180
# 6.0     177
# 9.0     169
# 11.0    165
# 12.0    162
# 2.0     159
# 3.0     157
# 1.0     154
# 4.0     151
# 8.0     150
# 5.0     148
# 7.0     146
# 13.0    139
# 17.0    133
# 14.0    132
# 16.0    125
# 15.0    125
# 18.0    107
# 19.0     55
# 20.0     54
# 21.0      1
# Name: count, dtype: int64

# %%
df3["away_club_position"] = df3["away_club_position"].fillna(10)

# %%
df3["away_club_position"].isnull().sum()
# Out:
# 0

# %%
df3["home_club_name"].isnull().sum()
# Out:
# 110

# %%
df3["home_club_name"].value_counts()
# Out:
# home_club_name
# Borussia Verein für Leibesübung 1900 e.V.    93
# FC Schalke 04                                90
# Stoke City                                   87
# Borussia Dortmund                            87
# Eintracht Frankfurt Fuayball AG              83
#                                              ..
# Lierse SK (- 2018)                            1
# Genoa Cricket and Football Club               1
# fc vitoria setubal                            1
# FK Dinamo Moskva                              1
# Bologna Football Club 1909                    1
# Name: count, Length: 253, dtype: int64

# %%
df3["home_club_name"] = df3["home_club_name"].fillna("Borussia Verein für Leibesübung 1900 e.V.")

# %%
df3["home_club_name"].isnull().sum()
# Out:
# 0

# %%
df3["away_club_name"].isnull().sum()
# Out:
# 63

# %%
df3["away_club_name"].value_counts()
# Out:
# away_club_name
# Borussia Dortmund                            95
# Stoke City                                   92
# eintracht frankfurt Football ag              91
# FC Schalke 04                                88
# Borussia Verein fur Leibesubung 1900 e.V.    87
#                                              ..
# FC Dordrecht                                  1
# Villarreal Club de Football S.A.D             1
# PFK Stal Kamyanske (-2018)                    1
# Elazigspor                                    1
# Desportivo Aves (- 2020)                      1
# Name: count, Length: 255, dtype: int64

# %%
df3["away_club_name"] = df3["away_club_name"].fillna("Borussia Dortmund")

# %%
df3["away_club_name"].isnull().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# game_id                     0
# competition_id              0
# season                      0
# round                       0
# date                        0
# home_club_goals             0
# away_club_goals             0
# home_club_position          0
# away_club_position          0
# home_club_manager_name      0
# away_club_manager_name      0
# stadium                     0
# attendance                115
# referee                     2
# home_club_formation         0
# away_club_formation         0
# home_club_name              0
# away_club_name              0
# aggregate                   0
# competition_type            0
# dtype: int64

# %%
df3["attendance"].isnull().sum()
# Out:
# 115

# %%
df3["attendance"].value_counts()
# Out:
# attendance
# 42100.0    24
# 51500.0    22
# 81360.0    20
# 24000.0    19
# 30150.0    17
#            ..
# 4360.0      1
# 34876.0     1
# 24344.0     1
# 19387.0     1
# 19423.0     1
# Name: count, Length: 2604, dtype: int64

# %%
df3["attendance"] = df3["attendance"].fillna(42100)

# %%
df3["attendance"].isnull().sum()
# Out:
# 0

# %%
df3["referee"].isnull().sum()
# Out:
# 2

# %%
df3["referee"].value_counts()
# Out:
# referee
# Dr. Felix Brych       60
# Felix Zwayer          59
# Manuel Graofe         58
# Anthony Taylor        57
# Martin Atkinson       57
#                       ..
# Kristinn Jakobsson     1
# Alper Ulusoy           1
# Manuel Oliveira        1
# Cosme Machado          1
# Antti Munukka          1
# Name: count, Length: 347, dtype: int64

# %%
df3["referee"] = df3["referee"].fillna("Dr. Felix Brych")

# %%
df3["referee"].isnull().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# game_id                   0
# competition_id            0
# season                    0
# round                     0
# date                      0
# home_club_goals           0
# away_club_goals           0
# home_club_position        0
# away_club_position        0
# home_club_manager_name    0
# away_club_manager_name    0
# stadium                   0
# attendance                0
# referee                   0
# home_club_formation       0
# away_club_formation       0
# home_club_name            0
# away_club_name            0
# aggregate                 0
# competition_type          0
# dtype: int64

# %%
df3
# Out:
#       game_id competition_id  season         round       date  \
# 0     2222734            RU1    2012  19. Matchday 2012-12-07
# 1     2224572            DK1    2012   3. Matchday 2012-07-28
# 2     2224628            DK1    2012  22. Matchday 2013-03-08
# 3     2224655            DK1    2012  22. Matchday 2013-03-10
# 4     2224729            DK1    2012   1. Matchday 2012-07-15
# ...       ...            ...     ...           ...        ...
# 3263  3296153            NLP    2019   Round of 16 2020-01-22
# 3264  2875216            DK1    2017  19. Matchday 2017-12-10
# 3265  3099247            BE1    2018  11. Matchday 2018-10-20
# 3266  2872273            GB1    2017  16. Matchday 2017-12-09
# 3267  2517322            FAC    2014   Third Round 2015-01-04
#
#       home_club_goals  away_club_goals  home_club_position  \
# 0                   2                3                11.0
# 1                   1                2                12.0
# ...

# %%
df4 = pd.read_excel('players.xlsx')
df4
# Out:
#      player_id                 name  last_season  current_club_id  \
# 0       124732  John Anthony Brooks         2023              533
# 1       223047      Emerson Hyndman         2018              903
# 2       307781         Lynden Gooch         2016              289
# 3       370846         Timothy Weah         2023              506
# 4       484756   Djordje Mihailovic         2023             1090
# ..         ...                  ...          ...              ...
# 147     273570        Desevio Payne         2020             1283
# 148     111783     Alejandro Bedoya         2015              995
# 149     160670             Joe Gyau         2014               16
# 150       3476         Brad Friedel         2014              148
# 151     504215       Giovanni Reyna         2023               16
#
#              player_code country_of_birth date_of_birth        sub_position  \
# 0    john-anthony-brooks          Germany    1993-01-28         Centre-Back
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    152 non-null    int64
#  1   name                         152 non-null    object
#  2   last_season                  152 non-null    int64
#  3   current_club_id              152 non-null    int64
#  4   player_code                  152 non-null    object
#  5   country_of_birth             152 non-null    object
#  6   date_of_birth                152 non-null    datetime64[ns]
#  7   sub_position                 152 non-null    object
#  8   position                     152 non-null    object
#  9   foot                         141 non-null    object
#  10  height_in_cm                 149 non-null    float64
#  11  market_value_in_eur          114 non-null    float64
# ...

# %%
df4.shape
# Out:
# (152, 15)

# %%
df4.columns
# Out:
# Index(['player_id', 'name', 'last_season', 'current_club_id', 'player_code',
#        'country_of_birth', 'date_of_birth', 'sub_position', 'position', 'foot',
#        'height_in_cm', 'market_value_in_eur', 'highest_market_value_in_eur',
#        'contract_expiration_date', 'agent_name'],
#       dtype='object')

# %%
df4.isnull().sum()
# Out:
# player_id                       0
# name                            0
# last_season                     0
# current_club_id                 0
# player_code                     0
# country_of_birth                0
# date_of_birth                   0
# sub_position                    0
# position                        0
# foot                           11
# height_in_cm                    3
# market_value_in_eur            38
# highest_market_value_in_eur     4
# contract_expiration_date       46
# agent_name                     45
# dtype: int64

# %%
df4["foot"].isnull().sum()
# Out:
# 11

# %%
df4["foot"].value_counts()
# Out:
# foot
# right    118
# left      16
# both       7
# Name: count, dtype: int64

# %%
df4["foot"] = df4["foot"].fillna("right")

# %%
df4["foot"].isnull().sum()
# Out:
# 0

# %%
df4["height_in_cm"].isnull().sum()
# Out:
# 3

# %%
df4["height_in_cm"].value_counts()
# Out:
# height_in_cm
# 183.0    15
# 180.0    13
# 185.0    13
# 178.0    10
# 193.0    10
# 191.0     9
# 175.0     8
# 177.0     8
# 176.0     6
# 190.0     6
# 184.0     5
# 170.0     5
# 188.0     5
# 182.0     5
# 186.0     4
# 173.0     4
# 172.0     3
# 194.0     3
# 187.0     3
# 189.0     2
# 179.0     2
# 174.0     2
# 181.0     1
# 197.0     1
# 200.0     1
# 162.0     1
# 195.0     1
# 192.0     1
# 204.0     1
# 171.0     1
# Name: count, dtype: int64

# %%
df4["height_in_cm"] = df4["height_in_cm"].fillna(183.0)

# %%
df4["height_in_cm"].isnull().sum()
# Out:
# 0

# %%
df4["market_value_in_eur"].isnull().sum()
# Out:
# 38

# %%
df4["market_value_in_eur"].value_counts()
# Out:
# market_value_in_eur
# 1000000.0     9
# 2000000.0     8
# 200000.0      7
# 400000.0      6
# 5000000.0     5
# 2500000.0     5
# 1500000.0     5
# 300000.0      5
# 800000.0      5
# 250000.0      4
# 150000.0      4
# 700000.0      4
# 500000.0      4
# 25000000.0    3
# 20000000.0    3
# 4000000.0     3
# 350000.0      3
# 10000000.0    3
# 8000000.0     2
# 100000.0      2
# 1200000.0     2
# 9000000.0     2
# 600000.0      2
# 12000000.0    2
# 850000.0      1
# 75000.0       1
# 650000.0      1
# 30000000.0    1
# 13000000.0    1
# 900000.0      1
# 1800000.0     1
# 15000000.0    1
# 14000000.0    1
# 750000.0      1
# 4500000.0     1
# 3000000.0     1
# 3500000.0     1
# 450000.0      1
# 125000.0      1
# 7000000.0     1
# Name: count, dtype: int64

# %%
df4["market_value_in_eur"] = df4["market_value_in_eur"].fillna(1000000.0)

# %%
df4["market_value_in_eur"].isnull().sum()
# Out:
# 0

# %%
df4["highest_market_value_in_eur"].isnull().sum()
# Out:
# 4

# %%
df4["highest_market_value_in_eur"].value_counts()
# Out:
# highest_market_value_in_eur
# 3000000.0     8
# 1000000.0     8
# 2000000.0     8
# 4000000.0     8
# 10000000.0    7
# 400000.0      6
# 300000.0      6
# 6000000.0     5
# 2500000.0     5
# 5000000.0     5
# 150000.0      4
# 3500000.0     4
# 15000000.0    4
# 500000.0      4
# 250000.0      4
# 600000.0      4
# 30000000.0    3
# 12000000.0    3
# 8000000.0     3
# 800000.0      3
# 4500000.0     3
# 1500000.0     3
# 9000000.0     2
# 50000.0       2
# 1200000.0     2
# 25000000.0    2
# 900000.0      2
# 125000.0      2
# 100000.0      2
# 7000000.0     2
# 950000.0      2
# 700000.0      2
# 60000000.0    1
# 13000000.0    1
# 1400000.0     1
# 75000.0       1
# 2200000.0     1
# 1850000.0     1
# 750000.0      1
# 550000.0      1
# 1600000.0     1
# 850000.0      1
# 1700000.0     1
# 1800000.0     1
# 20000000.0    1
# 1750000.0     1
# 2800000.0     1
# 350000.0      1
# 1300000.0     1
# 6500000.0     1
# 650000.0      1
# 42000000.0    1
# Name: count, dtype: int64

# %%
df4["highest_market_value_in_eur"] = df4["highest_market_value_in_eur"].fillna(3000000.0)

# %%
df4["highest_market_value_in_eur"].isnull().sum()
# Out:
# 0

# %%
df4["contract_expiration_date"].isnull().sum()
# Out:
# 46

# %%
df4["contract_expiration_date"].value_counts()
# Out:
# contract_expiration_date
# 2025-06-30    20
# 2024-06-30    18
# 2023-12-31    13
# 2026-06-30    11
# 2027-06-30    10
# 2024-12-31     9
# 2028-06-30     6
# 2025-12-31     6
# 2023-11-30     5
# 2023-06-30     2
# 2026-05-31     2
# 2023-05-31     1
# 2026-12-31     1
# 2027-12-31     1
# 2024-05-31     1
# Name: count, dtype: int64

# %%
df4["contract_expiration_date"] = df4["contract_expiration_date"].fillna("2025-06-30")

# %%
df4["contract_expiration_date"].isnull().sum()
# Out:
# 0

# %%
df4["agent_name"].isnull().sum()
# Out:
# 45

# %%
df4["agent_name"].isnull().sum()
# Out:
# 45

# %%
df4["agent_name"].value_counts()
# Out:
# agent_name
# Wasserman               19
# YMU Management Ltd.      7
# CAA Stellar              7
# PROSPORT Management      6
# Octagon                  6
# Mega Sports              5
# PRO FC                   4
# CCC                      3
# Unique Sports Group      3
# YMU Group                3
# AKA Global GmbH          2
# CAA Base Ltd             2
# SXI                      2
# SBM                      1
# TrueSports GmbH          1
# GROW                     1
# FC Enterprise            1
# Shot Sports              1
# INSUA GROUP              1
# Field Management         1
# ROGON                    1
# NVA SEG                  1
# fair-sport GmbH          1
# PG 120 Sport Agency      1
# CT10 management Srl      1
# More than Sport GmbH     1
# InterStarDeporte         1
# TOP Agency               1
# Gestifute                1
# Joes Blakborn            1
# ROOF                     1
# FGM                      1
# Promoesport              1
# ARP Sportmarketing       1
# ...

# %%
df4["agent_name"] = df4["agent_name"].fillna("Wasserman")

# %%
df4.isnull().sum()
# Out:
# player_id                      0
# name                           0
# last_season                    0
# current_club_id                0
# player_code                    0
# country_of_birth               0
# date_of_birth                  0
# sub_position                   0
# position                       0
# foot                           0
# height_in_cm                   0
# market_value_in_eur            0
# highest_market_value_in_eur    0
# contract_expiration_date       0
# agent_name                     0
# dtype: int64

# %%
df4
# Out:
#      player_id                 name  last_season  current_club_id  \
# 0       124732  John Anthony Brooks         2023              533
# 1       223047      Emerson Hyndman         2018              903
# 2       307781         Lynden Gooch         2016              289
# 3       370846         Timothy Weah         2023              506
# 4       484756   Djordje Mihailovic         2023             1090
# ..         ...                  ...          ...              ...
# 147     273570        Desevio Payne         2020             1283
# 148     111783     Alejandro Bedoya         2015              995
# 149     160670             Joe Gyau         2014               16
# 150       3476         Brad Friedel         2014              148
# 151     504215       Giovanni Reyna         2023               16
#
#              player_code country_of_birth date_of_birth        sub_position  \
# 0    john-anthony-brooks          Germany    1993-01-28         Centre-Back
# ...

# %%
# checking the null values once

# %%
df.isnull().sum()
# Out:
# appearance_id     0
# game_id           0
# player_id         0
# date              0
# player_name       0
# competition_id    0
# yellow_cards      0
# red_cards         0
# goals             0
# assists           0
# minutes_played    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# game_event_id       0
# date                0
# game_id             0
# minute              0
# type                0
# player_id           0
# description         0
# player_in_id        0
# player_assist_id    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# game_lineups_id    0
# game_id            0
# type               0
# number             0
# player_id          0
# player_name        0
# team_captain       0
# position           0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# game_id                   0
# competition_id            0
# season                    0
# round                     0
# date                      0
# home_club_goals           0
# away_club_goals           0
# home_club_position        0
# away_club_position        0
# home_club_manager_name    0
# away_club_manager_name    0
# stadium                   0
# attendance                0
# referee                   0
# home_club_formation       0
# away_club_formation       0
# home_club_name            0
# away_club_name            0
# aggregate                 0
# competition_type          0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# player_id                      0
# name                           0
# last_season                    0
# current_club_id                0
# player_code                    0
# country_of_birth               0
# date_of_birth                  0
# sub_position                   0
# position                       0
# foot                           0
# height_in_cm                   0
# market_value_in_eur            0
# highest_market_value_in_eur    0
# contract_expiration_date       0
# agent_name                     0
# dtype: int64

# %%
df
# Out:
#        appearance_id  game_id  player_id       date          player_name  \
# 0     2224728_119169  2224728     119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732     161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729      39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104     119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794      39475 2012-07-22       Sacha Kljestan
# ...              ...      ...        ...        ...                  ...
# 3563  3415291_537467  3415291     537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296     367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983     478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575     361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904     124732 2020-09-27  John Anthony Brooks
#
#      competition_id  yellow_cards  red_cards  goals  assists  minutes_played
# ...

# %%
df1
# Out:
#                          game_event_id       date  game_id  minute  \
# 0     c6a3c088ed8a38d4ce074dd73b20d3da 2012-08-19  2221641      62
# 1     02d605a5c2dc4f9a6721daa583fa5405 2012-08-26  2222536      54
# 2     b56c2e2e087cddb3cfe9e3d340975df9 2012-11-18  2222707      79
# 3     4a15d1fff4f476f48bb60092c61641d5 2012-11-23  2222721      72
# 4     daa97877f7edf2fda885b411d7197921 2013-05-17  2222782      63
# ...                                ...        ...      ...     ...
# 1844  4acebccbc824e45d51045d8c5e164341 2023-10-31  4194147       3
# 1845  159ad5633cf9d7c3a97b593efb6c3269 2023-10-31  4194147       9
# 1846  daa31f19aab26eec375884aef73c73b3 2023-10-31  4194147      65
# 1847  869a13060604e769290dafe0b1f14483 2023-11-01  4194152      70
# 1848  6b7ed06f13c1f67f0d7359c310f20ba0 2023-10-31  4194154      76
#
#                type  player_id  \
# 0     Substitutions       1335
# 1             Cards       1321
# 2     Substitutions     104203
# ...

# %%
df2
# Out:
#                       game_lineups_id  game_id             type  number  \
# 0    f2570d1504fc02f4b6c7608e8dcf89a3  4087925      substitutes      34
# 1    f5f0da93ea8e1d8bdd799658e7c8f7cb  4087928  starting_lineup      13
# 2    31a4d12ec23d604779d909d26c1b5410  4087929      substitutes      26
# 3    776dcbef98651450db76723cb7e3b4df  4087935      substitutes      26
# 4    6a35ef7495303f29e7f85dbd54547fb1  4087936  starting_lineup      13
# ..                                ...      ...              ...     ...
# 214  ec3d266094f99ca0a8847de827e37105  4194152  starting_lineup       7
# 215  667840cda9bdf3b0344b8e99b306cf38  4194152  starting_lineup      23
# 216  1c5d2f60ee777760f8a757aa10c42bb1  4194154  starting_lineup      13
# 217  99032084fd00ffbfee52c541a9f960ab  4204000      substitutes      14
# 218  5c9eaf6ebb621d43a0d6fd6a9e607ef9  4220942      substitutes      13
#
#      player_id          player_name  team_captain          position
# ...

# %%
df3
# Out:
#       game_id competition_id  season         round       date  \
# 0     2222734            RU1    2012  19. Matchday 2012-12-07
# 1     2224572            DK1    2012   3. Matchday 2012-07-28
# 2     2224628            DK1    2012  22. Matchday 2013-03-08
# 3     2224655            DK1    2012  22. Matchday 2013-03-10
# 4     2224729            DK1    2012   1. Matchday 2012-07-15
# ...       ...            ...     ...           ...        ...
# 3263  3296153            NLP    2019   Round of 16 2020-01-22
# 3264  2875216            DK1    2017  19. Matchday 2017-12-10
# 3265  3099247            BE1    2018  11. Matchday 2018-10-20
# 3266  2872273            GB1    2017  16. Matchday 2017-12-09
# 3267  2517322            FAC    2014   Third Round 2015-01-04
#
#       home_club_goals  away_club_goals  home_club_position  \
# 0                   2                3                11.0
# 1                   1                2                12.0
# ...

# %%
df4
# Out:
#      player_id                 name  last_season  current_club_id  \
# 0       124732  John Anthony Brooks         2023              533
# 1       223047      Emerson Hyndman         2018              903
# 2       307781         Lynden Gooch         2016              289
# 3       370846         Timothy Weah         2023              506
# 4       484756   Djordje Mihailovic         2023             1090
# ..         ...                  ...          ...              ...
# 147     273570        Desevio Payne         2020             1283
# 148     111783     Alejandro Bedoya         2015              995
# 149     160670             Joe Gyau         2014               16
# 150       3476         Brad Friedel         2014              148
# 151     504215       Giovanni Reyna         2023               16
#
#              player_code country_of_birth date_of_birth        sub_position  \
# 0    john-anthony-brooks          Germany    1993-01-28         Centre-Back
# ...

# %% [markdown]
# # Merging the data together

# %%
# appearances and players 
# df - appearances, df1 = game_events, df2 = game_lineups, df3 = games, df4 = players. 

app_merge = pd.merge(df,df4, on = "player_id", how = "left")
app_merge.reset_index(drop = True, inplace = True)
app_merge
# Out:
#        appearance_id  game_id  player_id       date          player_name  \
# 0     2224728_119169  2224728     119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732     161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729      39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104     119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794      39475 2012-07-22       Sacha Kljestan
# ...              ...      ...        ...        ...                  ...
# 3563  3415291_537467  3415291     537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296     367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983     478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575     361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904     124732 2020-09-27  John Anthony Brooks
#
#      competition_id  yellow_cards  red_cards  goals  assists  ...  \
# ...

# %%
# merging game events using the "game_id" which is in both columns 
# # df - appearances, df1 = game_events, df2 = game_lineups, df3 = games, df4 = players. app_merge = appearances and players

events_merge = pd.merge(app_merge, df1, on = "game_id", how = "left")
events_merge.reset_index(inplace = True)
events_merge
# Out:
#       index   appearance_id  game_id  player_id_x     date_x  \
# 0         0  2224728_119169  2224728       119169 2012-07-13
# 1         1  2224732_161244  2224732       161244 2012-07-14
# 2         2   2224729_39467  2224729        39467 2012-07-15
# 3         3  2232104_119169  2232104       119169 2012-07-19
# 4         4   2219794_39475  2219794        39475 2012-07-22
# ...     ...             ...      ...          ...        ...
# 3804   3804  3415291_537467  3415291       537467 2020-09-26
# 3805   3805  3415296_367423  3415296       367423 2020-09-26
# 3806   3806  3431983_478940  3431983       478940 2020-09-26
# 3807   3807  3450575_361104  3450575       361104 2020-09-26
# 3808   3808  3412904_124732  3412904       124732 2020-09-27
#
#               player_name competition_id  yellow_cards  red_cards  goals  ...  \
# 0         Aron Johannsson            DK1             0          0      0  ...
# ...

# %%
# merging game lineups with its common column 
# # df - appearances, df1 = game_events, df2 = game_lineups, df3 = games, df4 = players.
# app_merge = appearances and players, events_merge = appearances, players and game_events 

lineups_merge = pd.merge(app_merge, df2, on = "game_id", how = "left")
lineups_merge.reset_index(drop = True, inplace = True)
lineups_merge
# Out:
#        appearance_id  game_id  player_id_x       date        player_name_x  \
# 0     2224728_119169  2224728       119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732       161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729        39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104       119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794        39475 2012-07-22       Sacha Kljestan
# ...              ...      ...          ...        ...                  ...
# 3563  3415291_537467  3415291       537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296       367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983       478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575       361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904       124732 2020-09-27  John Anthony Brooks
#
#      competition_id  yellow_cards  red_cards  goals  assists  ...  \
# ...

# %%
# Merging the games column 
# df - appearances, df1 = game_events, df2 = game_lineups, df3 = games, df4 = players.
# app_merge = appearances and players, events_merge = appearances, players and game_events and 
# lineups_merge = appearances, players, game_event and game_lineups

Final_data = pd.merge(lineups_merge, df3, on = "game_id", how = "left")
Final_data.reset_index(drop = True, inplace = True)
Final_data
# Out:
#        appearance_id  game_id  player_id_x     date_x        player_name_x  \
# 0     2224728_119169  2224728       119169 2012-07-13      Aron Johannsson
# 1     2224732_161244  2224732       161244 2012-07-14        Conor O'Brien
# 2      2224729_39467  2224729        39467 2012-07-15     Clarence Goodson
# 3     2232104_119169  2232104       119169 2012-07-19      Aron Johannsson
# 4      2219794_39475  2219794        39475 2012-07-22       Sacha Kljestan
# ...              ...      ...          ...        ...                  ...
# 3563  3415291_537467  3415291       537467 2020-09-26        Joseph Efford
# 3564  3415296_367423  3415296       367423 2020-09-26         Chris Durkin
# 3565  3431983_478940  3431983       478940 2020-09-26        Reggie Cannon
# 3566  3450575_361104  3450575       361104 2020-09-26         Sergino Dest
# 3567  3412904_124732  3412904       124732 2020-09-27  John Anthony Brooks
#
# ...

# %%
Final_data.isnull().sum()
# Out:
# appearance_id                     0
# game_id                           0
# player_id_x                       0
# date_x                            0
# player_name_x                     0
# competition_id_x                  0
# yellow_cards                      0
# red_cards                         0
# goals                             0
# assists                           0
# minutes_played                    0
# name                              0
# last_season                       0
# current_club_id                   0
# player_code                       0
# country_of_birth                  0
# date_of_birth                     0
# sub_position                      0
# position_x                        0
# foot                              0
# height_in_cm                      0
# market_value_in_eur               0
# highest_market_value_in_eur       0
# contract_expiration_date          0
# agent_name                        0
# game_lineups_id                3568
# ...

# %% [markdown]
# game_lineups_id                3568
# type                           3568
# number                         3568
# player_id_y                    3568
# player_name_y                  3568
# team_captain                   3568
# position_y                     3568
# home_club_formation               0
# away_club_formation               0

# %%
Final_Data = Final_data.drop(columns = ["game_lineups_id","type","number","player_id_y","player_name_y","team_captain",
                                        "position_y","home_club_formation","away_club_formation","date_y","competition_id_y",
                                       "game_id","appearance_id","player_id_x"])

# %%
Final_Data
# Out:
#          date_x        player_name_x competition_id_x  yellow_cards  \
# 0    2012-07-13      Aron Johannsson              DK1             0
# 1    2012-07-14        Conor O'Brien              DK1             0
# 2    2012-07-15     Clarence Goodson              DK1             0
# 3    2012-07-19      Aron Johannsson              ELQ             0
# 4    2012-07-22       Sacha Kljestan             BESC             0
# ...         ...                  ...              ...           ...
# 3563 2020-09-26        Joseph Efford              BE1             0
# 3564 2020-09-26         Chris Durkin              BE1             1
# 3565 2020-09-26        Reggie Cannon              PO1             0
# 3566 2020-09-26         Sergino Dest              NL1             0
# 3567 2020-09-27  John Anthony Brooks               L1             1
#
#       red_cards  goals  assists  minutes_played                 name  \
# 0             0      0        0              90      Aron Johannsson
# ...

# %%
Final_Data.isnull().sum()
# Out:
# date_x                         0
# player_name_x                  0
# competition_id_x               0
# yellow_cards                   0
# red_cards                      0
# goals                          0
# assists                        0
# minutes_played                 0
# name                           0
# last_season                    0
# current_club_id                0
# player_code                    0
# country_of_birth               0
# date_of_birth                  0
# sub_position                   0
# position_x                     0
# foot                           0
# height_in_cm                   0
# market_value_in_eur            0
# highest_market_value_in_eur    0
# contract_expiration_date       0
# agent_name                     0
# season                         0
# round                          0
# home_club_goals                0
# away_club_goals                0
# home_club_position             0
# away_club_position             0
# ...

# %%
Final_Data.columns
# Out:
# Index(['date_x', 'player_name_x', 'competition_id_x', 'yellow_cards',
#        'red_cards', 'goals', 'assists', 'minutes_played', 'name',
#        'last_season', 'current_club_id', 'player_code', 'country_of_birth',
#        'date_of_birth', 'sub_position', 'position_x', 'foot', 'height_in_cm',
#        'market_value_in_eur', 'highest_market_value_in_eur',
#        'contract_expiration_date', 'agent_name', 'season', 'round',
#        'home_club_goals', 'away_club_goals', 'home_club_position',
#        'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee',
#        'home_club_name', 'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
Final_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3568 entries, 0 to 3567
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date_x                       3568 non-null   datetime64[ns]
#  1   player_name_x                3568 non-null   object
#  2   competition_id_x             3568 non-null   object
#  3   yellow_cards                 3568 non-null   int64
#  4   red_cards                    3568 non-null   int64
#  5   goals                        3568 non-null   int64
#  6   assists                      3568 non-null   int64
#  7   minutes_played               3568 non-null   int64
#  8   name                         3568 non-null   object
#  9   last_season                  3568 non-null   int64
#  10  current_club_id              3568 non-null   int64
#  11  player_code                  3568 non-null   object
#  12  country_of_birth             3568 non-null   object
# ...

# %%
Final_Data.shape
# Out:
# (3568, 37)

# %%
Final_Data.isnull().sum()
# Out:
# date_x                         0
# player_name_x                  0
# competition_id_x               0
# yellow_cards                   0
# red_cards                      0
# goals                          0
# assists                        0
# minutes_played                 0
# name                           0
# last_season                    0
# current_club_id                0
# player_code                    0
# country_of_birth               0
# date_of_birth                  0
# sub_position                   0
# position_x                     0
# foot                           0
# height_in_cm                   0
# market_value_in_eur            0
# highest_market_value_in_eur    0
# contract_expiration_date       0
# agent_name                     0
# season                         0
# round                          0
# home_club_goals                0
# away_club_goals                0
# home_club_position             0
# away_club_position             0
# ...

# %%
#numerical columns
Num = Final_Data.select_dtypes(exclude = 'object')
Num
# Out:
#          date_x  yellow_cards  red_cards  goals  assists  minutes_played  \
# 0    2012-07-13             0          0      0        0              90
# 1    2012-07-14             0          0      1        0              90
# 2    2012-07-15             0          0      0        0              90
# 3    2012-07-19             0          0      0        0              74
# 4    2012-07-22             0          0      0        0               3
# ...         ...           ...        ...    ...      ...             ...
# 3563 2020-09-26             0          0      1        0              77
# 3564 2020-09-26             1          0      0        0              84
# 3565 2020-09-26             0          0      0        0              90
# 3566 2020-09-26             0          0      0        0               6
# 3567 2020-09-27             1          0      0        0              90
#
#       last_season  current_club_id date_of_birth  height_in_cm  \
# ...

# %%
Cat = Final_Data.select_dtypes(include = 'object')
Cat
# Out:
#             player_name_x competition_id_x                 name  \
# 0         Aron Johannsson              DK1      Aron Johannsson
# 1           Conor O'Brien              DK1        Conor O'Brien
# 2        Clarence Goodson              DK1     Clarence Goodson
# 3         Aron Johannsson              ELQ      Aron Johannsson
# 4          Sacha Kljestan             BESC       Sacha Kljestan
# ...                   ...              ...                  ...
# 3563        Joseph Efford              BE1        Joseph Efford
# 3564         Chris Durkin              BE1         Chris Durkin
# 3565        Reggie Cannon              PO1        Reggie Cannon
# 3566         Sergino Dest              NL1         Sergino Dest
# 3567  John Anthony Brooks               L1  John Anthony Brooks
#
#               player_code country_of_birth        sub_position position_x  \
# 0         aron-johannsson    United States      Centre-Forward     Attack
# ...

# %%
num_list = list(Num.columns)
num_list
# Out:
# ['date_x',
#  'yellow_cards',
#  'red_cards',
#  'goals',
#  'assists',
#  'minutes_played',
#  'last_season',
#  'current_club_id',
#  'date_of_birth',
#  'height_in_cm',
#  'market_value_in_eur',
#  'highest_market_value_in_eur',
#  'contract_expiration_date',
#  'season',
#  'home_club_goals',
#  'away_club_goals',
#  'home_club_position',
#  'away_club_position',
#  'attendance']

# %%
cat_list = list(Cat.columns)
cat_list
# Out:
# ['player_name_x',
#  'competition_id_x',
#  'name',
#  'player_code',
#  'country_of_birth',
#  'sub_position',
#  'position_x',
#  'foot',
#  'agent_name',
#  'round',
#  'home_club_manager_name',
#  'away_club_manager_name',
#  'stadium',
#  'referee',
#  'home_club_name',
#  'away_club_name',
#  'aggregate',
#  'competition_type']

# %%
table = [num_list, cat_list]
print(tabulate({"Categorical Column": cat_list, "Numerical Column": num_list}, 
               headers = ["Categorical Column","Numerical Column"]))
# Out:
# Categorical Column      Numerical Column
# ----------------------  ---------------------------
# player_name_x           date_x
# competition_id_x        yellow_cards
# name                    red_cards
# player_code             goals
# country_of_birth        assists
# sub_position            minutes_played
# position_x              last_season
# foot                    current_club_id
# agent_name              date_of_birth
# round                   height_in_cm
# home_club_manager_name  market_value_in_eur
# away_club_manager_name  highest_market_value_in_eur
# stadium                 contract_expiration_date
# referee                 season
# home_club_name          home_club_goals
# away_club_name          away_club_goals
# aggregate               home_club_position
# competition_type        away_club_position
#                         attendance

# %% [markdown]
# ## CONNECTING TO MYSQL

# %%
import mysql.connector as sql

# %%
from sqlalchemy import create_engine

# %%
db = sql.connect(host = "localhost", user = "root", password = "yashuanbu1602", database = "school")

# %%
mycursor=db.cursor()

# %%
mycursor.execute("create database Football_Data")

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}".
                       format(host='localhost', db='Football_Data', user='root', pw='yashuanbu1602'))

# %%
Final_Data.to_sql("Merged_Cleaned_Data", engine,index = False)
# Out:
# 3568

# %%
Final_Data.to_excel('C8_Football_Data_Preprocessed_Merged_&Cleaned.xlsx', index=False)
